# %% [markdown]
# # Task 6.1: Sourcing Open Data (NHL Player Stats Project)

# %% [markdown]
# ### The script contain the following points:
#
# 1)Importing libraries to computer (Pandas, NumPy, OS)
#
# 2)Importing Data to Notebook / Turning Project Folder Path Into a String (NHL Players Dataset)
#
# 3)Data Checks/Cleaning
#
# 4)Basic Descriptive Statistics

# %% [markdown]
# ## 01. Importing Libraries to Computer (Pandas, NumPy, and OS)

# %%
# Importing libraries to computer
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Importing Data to Notebook / Turning Project Folder Path Into a String (NHL Players Dataset)

# %%
# Creating a data importing shortcut called 'path' for the NHL project folder to make importing data easier and cleaner
path =r'/Users/drewsmith/Desktop/NHL Player Stats Analysis'

# %%
# Utilizing the newly created 'path' shortcut to import the 'NHL Player Data' dataset
nhl_df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'NHL Player Data Stats.csv'), index_col = False)

# %% [markdown]
# ## 03. Data Checks/Cleaning

# %%
nhl_df.head()
# Out:
#    Rk                       Player  Age Pos   Tm  GP   G   A  PTS  plusminus  \
# 0   1     Connor McDavid\mcdavco01   20   C  EDM  82  30  70  100         27
# 1   2      Sidney Crosby\crosbsi01   29   C  PIT  75  44  45   89         17
# 2   3        Patrick Kane\kanepa01   28  RW  CHI  82  34  55   89         11
# 3   4  Nicklas Backstrom\backsni02   29   C  WSH  82  23  63   86         17
# 4   5    Nikita Kucherov\kucheni01   23  RW  TBL  74  40  45   85         13
#
#    ...   TOI       ATOI   BLK  HIT    FOW    FOL  FO_percent  HART  Votes  \
# 0  ...  1733  21.133333  29.0   34  348.0  458.0        43.2     1   1604
# 1  ...  1491  19.883333  27.0   80  842.0  906.0        48.2     0   1104
# 2  ...  1754  21.400000  15.0   28    7.0   44.0        13.7     0    206
# 3  ...  1497  18.266667  33.0   45  685.0  648.0        51.4     0     60
# 4  ...  1438  19.433333  20.0   30    0.0    0.0         0.0     0    119
#
#    Season
# 0    2017
# 1    2017
# 2    2017
# 3    2017
# 4    2017
#
# [5 rows x 31 columns]

# %%
# Doesn't assign any options to the max number of columns so the 'head()' function can display all columns
pd.options.display.max_columns = None

# %%
nhl_df.shape
# Out:
# (13186, 31)

# %% [markdown]
# ### Renamed columns

# %%
# Renamed columns to be more specific and easier to understand
nhl_df.rename(columns = {'Rk':'Rank', 'Pos':'Position','Tm':'Team','GP':'Games_Played','G':'Goals','A':'Assists','PTS':'Points','plusminus':'Plus_Minus','PIM':'Penalty_Minutes','PS':'Point_Shares','EV':'Even_Strength_Goals','PP':'Powerplay_Goals','SH':'Shorthanded_Goals','GW':'Game_Winning_Goals','S':'Shots','S_percent':'Shooting_Percentage','TOI':'Time_On_Ice','ATOI':'Avg_Time_On_Ice','BLK':'Blocks','HIT':'Hits','FOW':'Faceoff_Wins','FOL':'Faceoff_Losses','FO_percent':'Faceoff_Percentage','HART':'Hart_Winner?'},inplace = True)

# %%
nhl_df.head()
# Out:
#    Rank                       Player  Age Position Team  Games_Played  Goals  \
# 0     1     Connor McDavid\mcdavco01   20        C  EDM            82     30
# 1     2      Sidney Crosby\crosbsi01   29        C  PIT            75     44
# 2     3        Patrick Kane\kanepa01   28       RW  CHI            82     34
# 3     4  Nicklas Backstrom\backsni02   29        C  WSH            82     23
# 4     5    Nikita Kucherov\kucheni01   23       RW  TBL            74     40
#
#    Assists  Points  Plus_Minus  Penalty_Minutes  Point_Shares  \
# 0       70     100          27               26          12.8
# 1       45      89          17               24          12.3
# 2       55      89          11               32          10.8
# 3       63      86          17               38           9.9
# 4       45      85          13               38          12.0
#
#    Even_Strength_Goals  Powerplay_Goals  Shorthanded_Goals  \
# 0                   26                3                  1
# 1                   30               14                  0
# 2                   27                7                  0
# 3                   15                8                  0
# 4                   23               17                  0
#
#    Game_Winning_Goals  EV.1  PP.1  SH.1  Shots  Shooting_Percentage  \
# 0                   6    45    24     1    251                 12.0
# 1                   5    34    11     0    255                 17.3
# 2                   5    39    16     0    292                 11.6
# 3                   5    36    27     0    162                 14.2
# 4                   7    30    15     0    246                 16.3
#
#    Time_On_Ice  Avg_Time_On_Ice  Blocks  Hits  Faceoff_Wins  Faceoff_Losses  \
# 0         1733        21.133333    29.0    34         348.0           458.0
# 1         1491        19.883333    27.0    80         842.0           906.0
# 2         1754        21.400000    15.0    28           7.0            44.0
# 3         1497        18.266667    33.0    45         685.0           648.0
# 4         1438        19.433333    20.0    30           0.0             0.0
#
#    Faceoff_Percentage  Hart_Winner?  Votes  Season
# 0                43.2             1   1604    2017
# 1                48.2             0   1104    2017
# 2                13.7             0    206    2017
# 3                51.4             0     60    2017
# 4                 0.0             0    119    2017

# %% [markdown]
# ### There are a few missing values found

# %%
# Checks for null values in all columns
nhl_df.isnull().sum()
# Out:
# Rank                     0
# Player                   0
# Age                      0
# Position                 0
# Team                     0
# Games_Played             0
# Goals                    0
# Assists                  0
# Points                   0
# Plus_Minus               0
# Penalty_Minutes          0
# Point_Shares             0
# Even_Strength_Goals      0
# Powerplay_Goals          0
# Shorthanded_Goals        0
# Game_Winning_Goals       0
# EV.1                     0
# PP.1                     0
# SH.1                     0
# Shots                    0
# Shooting_Percentage    124
# Time_On_Ice              0
# Avg_Time_On_Ice          0
# Blocks                   1
# Hits                     0
# Faceoff_Wins             1
# Faceoff_Losses           1
# Faceoff_Percentage     311
# Hart_Winner?             0
# Votes                    0
# Season                   0
# dtype: int64

# %%
# Creates a subset with only rows containing missing values under a specific column (re-did the function with each column)
nhl_missing = nhl_df[nhl_df['Shooting_Percentage'].isnull() ==True]

# %%
nhl_missing.head()
# Out:
#        Rank                    Player  Age Position Team  Games_Played  Goals  \
# 10338   687     Nate Guenin\guenina01   24        D  PHI             9      0
# 10394   743    Martin Lojek\lojekma01   21        D  FLA             3      0
# 10422   771     Eric Cairns\cairner01   32        D  PIT             1      0
# 10423   772  Darcy Campbell\campbda02   22        D  CBJ             1      0
# 10424   773        Mike Card\cardmi01   20        D  BUF             4      0
#
#        Assists  Points  Plus_Minus  Penalty_Minutes  Point_Shares  \
# 10338        2       2           0                4           0.3
# 10394        1       1           2                0           0.3
# 10422        0       0           0                5           0.0
# 10423        0       0           0                0           0.0
# 10424        0       0           0                0           0.0
#
#        Even_Strength_Goals  Powerplay_Goals  Shorthanded_Goals  \
# 10338                    0                0                  0
# 10394                    0                0                  0
# 10422                    0                0                  0
# 10423                    0                0                  0
# 10424                    0                0                  0
#
#        Game_Winning_Goals  EV.1  PP.1  SH.1  Shots  Shooting_Percentage  \
# 10338                   0     2     0     0      0                  NaN
# 10394                   0     1     0     0      0                  NaN
# 10422                   0     0     0     0      0                  NaN
# 10423                   0     0     0     0      0                  NaN
# 10424                   0     0     0     0      0                  NaN
#
#        Time_On_Ice  Avg_Time_On_Ice  Blocks  Hits  Faceoff_Wins  \
# 10338           78         8.666667     0.0     0           0.0
# 10394           25         8.383333     0.0     0           0.0
# 10422            1         0.700000     0.0     0           0.0
# 10423            6         5.683333     0.0     0           0.0
# 10424           18         4.566667     0.0     0           0.0
#
#        Faceoff_Losses  Faceoff_Percentage  Hart_Winner?  Votes  Season
# 10338             0.0                 0.0             0      0    2007
# 10394             0.0                 0.0             0      0    2007
# 10422             0.0                 0.0             0      0    2007
# 10423             0.0                 0.0             0      0    2007
# 10424             0.0                 0.0             0      0    2007

# %% [markdown]
# ### What I did with the missing values

# %%
# Assigning all missing values with a zero (explained why below)
nhl_new = nhl_df.replace(np.nan,0)

# %% [markdown]
# ##### The players with missing values in the 'Shooting_Percentage' column have 0 goals therefore have a 0% shooting percentage. Missing values replaced with zeros.
#
# ##### The Faceoff_Percentage column has missing values since some players are not centermen therefore they haven’t taken any faceoffs (only centermen take faceoffs). Missing values replaced with zeros.
#
# ##### The Blocks, Faceoff_Wins, and Faceoff_Losses column has one player who has only played 1 game and is a defenseman (position doesn't take faceoffs). Missing values replaced with zeros.
#
# ##### All of these missing values are replaced with zeros.

# %%
# Checks for null values in all columns
nhl_new.isnull().sum()
# Out:
# Rank                   0
# Player                 0
# Age                    0
# Position               0
# Team                   0
# Games_Played           0
# Goals                  0
# Assists                0
# Points                 0
# Plus_Minus             0
# Penalty_Minutes        0
# Point_Shares           0
# Even_Strength_Goals    0
# Powerplay_Goals        0
# Shorthanded_Goals      0
# Game_Winning_Goals     0
# EV.1                   0
# PP.1                   0
# SH.1                   0
# Shots                  0
# Shooting_Percentage    0
# Time_On_Ice            0
# Avg_Time_On_Ice        0
# Blocks                 0
# Hits                   0
# Faceoff_Wins           0
# Faceoff_Losses         0
# Faceoff_Percentage     0
# Hart_Winner?           0
# Votes                  0
# Season                 0
# dtype: int64

# %% [markdown]
# ### Checking for Duplicates

# %%
# Displays only rows that are duplicates in nhl_new dataframe under a new subset
nhl_dups = nhl_new[nhl_new.duplicated()]

# %%
# No duplicates found
nhl_dups
# Out:
# Empty DataFrame
# Columns: [Rank, Player, Age, Position, Team, Games_Played, Goals, Assists, Points, Plus_Minus, Penalty_Minutes, Point_Shares, Even_Strength_Goals, Powerplay_Goals, Shorthanded_Goals, Game_Winning_Goals, EV.1, PP.1, SH.1, Shots, Shooting_Percentage, Time_On_Ice, Avg_Time_On_Ice, Blocks, Hits, Faceoff_Wins, Faceoff_Losses, Faceoff_Percentage, Hart_Winner?, Votes, Season]
# Index: []

# %% [markdown]
# ### Checking Datatypes

# %%
# Shows the datatypes for all columns in the nhl_new dataset
nhl_new.dtypes
# Out:
# Rank                     int64
# Player                  object
# Age                      int64
# Position                object
# Team                    object
# Games_Played             int64
# Goals                    int64
# Assists                  int64
# Points                   int64
# Plus_Minus               int64
# Penalty_Minutes          int64
# Point_Shares           float64
# Even_Strength_Goals      int64
# Powerplay_Goals          int64
# Shorthanded_Goals        int64
# Game_Winning_Goals       int64
# EV.1                     int64
# PP.1                     int64
# SH.1                     int64
# Shots                    int64
# Shooting_Percentage    float64
# Time_On_Ice              int64
# Avg_Time_On_Ice        float64
# Blocks                 float64
# Hits                     int64
# Faceoff_Wins           float64
# Faceoff_Losses         float64
# Faceoff_Percentage     float64
# Hart_Winner?             int64
# Votes                    int64
# Season                   int64
# dtype: object

# %% [markdown]
# ### Removing Unnecessary Columns

# %%
# Dropping these columns since they are unnecessary and contain false data
nhl_newer = nhl_new.drop(columns = ['EV.1','PP.1','SH.1'])

# %%
# Checking to see if the column removal worked
nhl_newer.head()
# Out:
#    Rank                       Player  Age Position Team  Games_Played  Goals  \
# 0     1     Connor McDavid\mcdavco01   20        C  EDM            82     30
# 1     2      Sidney Crosby\crosbsi01   29        C  PIT            75     44
# 2     3        Patrick Kane\kanepa01   28       RW  CHI            82     34
# 3     4  Nicklas Backstrom\backsni02   29        C  WSH            82     23
# 4     5    Nikita Kucherov\kucheni01   23       RW  TBL            74     40
#
#    Assists  Points  Plus_Minus  Penalty_Minutes  Point_Shares  \
# 0       70     100          27               26          12.8
# 1       45      89          17               24          12.3
# 2       55      89          11               32          10.8
# 3       63      86          17               38           9.9
# 4       45      85          13               38          12.0
#
#    Even_Strength_Goals  Powerplay_Goals  Shorthanded_Goals  \
# 0                   26                3                  1
# 1                   30               14                  0
# 2                   27                7                  0
# 3                   15                8                  0
# 4                   23               17                  0
#
#    Game_Winning_Goals  Shots  Shooting_Percentage  Time_On_Ice  \
# 0                   6    251                 12.0         1733
# 1                   5    255                 17.3         1491
# 2                   5    292                 11.6         1754
# 3                   5    162                 14.2         1497
# 4                   7    246                 16.3         1438
#
#    Avg_Time_On_Ice  Blocks  Hits  Faceoff_Wins  Faceoff_Losses  \
# 0        21.133333    29.0    34         348.0           458.0
# 1        19.883333    27.0    80         842.0           906.0
# 2        21.400000    15.0    28           7.0            44.0
# 3        18.266667    33.0    45         685.0           648.0
# 4        19.433333    20.0    30           0.0             0.0
#
#    Faceoff_Percentage  Hart_Winner?  Votes  Season
# 0                43.2             1   1604    2017
# 1                48.2             0   1104    2017
# 2                13.7             0    206    2017
# 3                51.4             0     60    2017
# 4                 0.0             0    119    2017

# %% [markdown]
# ### Assigning 'Hart_Winner?' column with better inputs

# %% [markdown]
# ##### Changing the inputs in the 'Hart_Winner?' column into a new column with the loc function

# %%
# Uses loc function to group hart trophy winner status under a value name
nhl_newer.loc[nhl_newer['Hart_Winner?'] <= 0, 'Hart_Trophy?'] = 'No'

# %%
# Uses loc function to group hart trophy winner status under a value name
nhl_newer.loc[nhl_newer['Hart_Winner?'] >= 1, 'Hart_Trophy?'] = 'Yes'

# %%
nhl_newer.head()
# Out:
#    Rank                       Player  Age Position Team  Games_Played  Goals  \
# 0     1     Connor McDavid\mcdavco01   20        C  EDM            82     30
# 1     2      Sidney Crosby\crosbsi01   29        C  PIT            75     44
# 2     3        Patrick Kane\kanepa01   28       RW  CHI            82     34
# 3     4  Nicklas Backstrom\backsni02   29        C  WSH            82     23
# 4     5    Nikita Kucherov\kucheni01   23       RW  TBL            74     40
#
#    Assists  Points  Plus_Minus  Penalty_Minutes  Point_Shares  \
# 0       70     100          27               26          12.8
# 1       45      89          17               24          12.3
# 2       55      89          11               32          10.8
# 3       63      86          17               38           9.9
# 4       45      85          13               38          12.0
#
#    Even_Strength_Goals  Powerplay_Goals  Shorthanded_Goals  \
# 0                   26                3                  1
# 1                   30               14                  0
# 2                   27                7                  0
# 3                   15                8                  0
# 4                   23               17                  0
#
#    Game_Winning_Goals  Shots  Shooting_Percentage  Time_On_Ice  \
# 0                   6    251                 12.0         1733
# 1                   5    255                 17.3         1491
# 2                   5    292                 11.6         1754
# 3                   5    162                 14.2         1497
# 4                   7    246                 16.3         1438
#
#    Avg_Time_On_Ice  Blocks  Hits  Faceoff_Wins  Faceoff_Losses  \
# 0        21.133333    29.0    34         348.0           458.0
# 1        19.883333    27.0    80         842.0           906.0
# 2        21.400000    15.0    28           7.0            44.0
# 3        18.266667    33.0    45         685.0           648.0
# 4        19.433333    20.0    30           0.0             0.0
#
#    Faceoff_Percentage  Hart_Winner?  Votes  Season Hart_Trophy?
# 0                43.2             1   1604    2017          Yes
# 1                48.2             0   1104    2017           No
# 2                13.7             0    206    2017           No
# 3                51.4             0     60    2017           No
# 4                 0.0             0    119    2017           No

# %%
# Check value counts per group to see if new variable is correct
nhl_newer['Hart_Trophy?'].value_counts(dropna = False)
# Out:
# No     13172
# Yes       14
# Name: Hart_Trophy?, dtype: int64

# %% [markdown]
# ### Reordering Columns

# %%
# Creating a new column order
columns = ['Season','Rank','Player','Age','Position','Team','Games_Played','Goals','Assists','Points','Plus_Minus','Penalty_Minutes','Point_Shares','Even_Strength_Goals','Powerplay_Goals','Shorthanded_Goals','Game_Winning_Goals','Shots','Shooting_Percentage','Time_On_Ice','Avg_Time_On_Ice', 'Blocks','Hits','Faceoff_Wins', 'Faceoff_Losses','Faceoff_Percentage','Hart_Winner?','Hart_Trophy?','Votes']

# %%
nhl_reindex = nhl_newer.reindex(columns=columns)

# %%
nhl_reindex.head()
# Out:
#    Season  Rank                       Player  Age Position Team  Games_Played  \
# 0    2017     1     Connor McDavid\mcdavco01   20        C  EDM            82
# 1    2017     2      Sidney Crosby\crosbsi01   29        C  PIT            75
# 2    2017     3        Patrick Kane\kanepa01   28       RW  CHI            82
# 3    2017     4  Nicklas Backstrom\backsni02   29        C  WSH            82
# 4    2017     5    Nikita Kucherov\kucheni01   23       RW  TBL            74
#
#    Goals  Assists  Points  Plus_Minus  Penalty_Minutes  Point_Shares  \
# 0     30       70     100          27               26          12.8
# 1     44       45      89          17               24          12.3
# 2     34       55      89          11               32          10.8
# 3     23       63      86          17               38           9.9
# 4     40       45      85          13               38          12.0
#
#    Even_Strength_Goals  Powerplay_Goals  Shorthanded_Goals  \
# 0                   26                3                  1
# 1                   30               14                  0
# 2                   27                7                  0
# 3                   15                8                  0
# 4                   23               17                  0
#
#    Game_Winning_Goals  Shots  Shooting_Percentage  Time_On_Ice  \
# 0                   6    251                 12.0         1733
# 1                   5    255                 17.3         1491
# 2                   5    292                 11.6         1754
# 3                   5    162                 14.2         1497
# 4                   7    246                 16.3         1438
#
#    Avg_Time_On_Ice  Blocks  Hits  Faceoff_Wins  Faceoff_Losses  \
# 0        21.133333    29.0    34         348.0           458.0
# 1        19.883333    27.0    80         842.0           906.0
# 2        21.400000    15.0    28           7.0            44.0
# 3        18.266667    33.0    45         685.0           648.0
# 4        19.433333    20.0    30           0.0             0.0
#
#    Faceoff_Percentage  Hart_Winner? Hart_Trophy?  Votes
# 0                43.2             1          Yes   1604
# 1                48.2             0           No   1104
# 2                13.7             0           No    206
# 3                51.4             0           No     60
# 4                 0.0             0           No    119

# %% [markdown]
# ### Dropping Column

# %%
# Dropping this column since it is now unnecessary 
nhl_cleaned = nhl_reindex.drop(columns = ['Hart_Winner?'])

# %%
nhl_cleaned.head()
# Out:
#    Season  Rank                       Player  Age Position Team  Games_Played  \
# 0    2017     1     Connor McDavid\mcdavco01   20        C  EDM            82
# 1    2017     2      Sidney Crosby\crosbsi01   29        C  PIT            75
# 2    2017     3        Patrick Kane\kanepa01   28       RW  CHI            82
# 3    2017     4  Nicklas Backstrom\backsni02   29        C  WSH            82
# 4    2017     5    Nikita Kucherov\kucheni01   23       RW  TBL            74
#
#    Goals  Assists  Points  Plus_Minus  Penalty_Minutes  Point_Shares  \
# 0     30       70     100          27               26          12.8
# 1     44       45      89          17               24          12.3
# 2     34       55      89          11               32          10.8
# 3     23       63      86          17               38           9.9
# 4     40       45      85          13               38          12.0
#
#    Even_Strength_Goals  Powerplay_Goals  Shorthanded_Goals  \
# 0                   26                3                  1
# 1                   30               14                  0
# 2                   27                7                  0
# 3                   15                8                  0
# 4                   23               17                  0
#
#    Game_Winning_Goals  Shots  Shooting_Percentage  Time_On_Ice  \
# 0                   6    251                 12.0         1733
# 1                   5    255                 17.3         1491
# 2                   5    292                 11.6         1754
# 3                   5    162                 14.2         1497
# 4                   7    246                 16.3         1438
#
#    Avg_Time_On_Ice  Blocks  Hits  Faceoff_Wins  Faceoff_Losses  \
# 0        21.133333    29.0    34         348.0           458.0
# 1        19.883333    27.0    80         842.0           906.0
# 2        21.400000    15.0    28           7.0            44.0
# 3        18.266667    33.0    45         685.0           648.0
# 4        19.433333    20.0    30           0.0             0.0
#
#    Faceoff_Percentage Hart_Trophy?  Votes
# 0                43.2          Yes   1604
# 1                48.2           No   1104
# 2                13.7           No    206
# 3                51.4           No     60
# 4                 0.0           No    119

# %%
nhl_cleaned.shape
# Out:
# (13186, 28)

# %% [markdown]
# ### Isolating 2004 Season Player Data / Exporting It

# %% [markdown]
# #### I want to only analyze the NHL salary cap era (2005 season to now) therefore the 2004 dataset isn't necessary. However, it could be used for comparison in the future (salary cap era vs non-salary cap era)

# %%
# Creating a subset with only players in the 2004 season
non_salary_cap_data = nhl_cleaned[nhl_cleaned['Season']==2004]

# %%
non_salary_cap_data
# Out:
#        Season  Rank                      Player  Age Position Team  \
# 11380    2004  1729  Martin St. Louis\stlouma01   28       RW  TBL
# 11381    2004  1730    Ilya Kovalchuk\kovalil01   20       LW  ATL
# 11382    2004  1731        Joe Sakic*\sakicjo01   34        C  COL
# 11383    2004  1732    Markus Naslund\nasluma02   30       LW  VAN
# 11384    2004  1733      Marian Hossa\hossama01   25       RW  OTT
# ...       ...   ...                         ...  ...      ...  ...
# 12291    2004  2640       Peter White\whitepe01   34        C  PHI
# 12292    2004  2641        Clarke Wilm\wilmcl01   27        C  TOR
# 12293    2004  2642  Jeremy Yablonski\yabloje01   23       RW  STL
# 12294    2004  2643     Nolan Yonkman\yonkmno01   22        D  WSH
# 12295    2004  2644  Miroslav Zalesak\zalesmi01   24       RW  SJS
#
#        Games_Played  Goals  Assists  Points  Plus_Minus  Penalty_Minutes  \
# 11380            82     38       56      94          35               24
# 11381            81     41       46      87         -10               63
# 11382            81     33       54      87          11               42
# 11383            78     35       49      84          24               58
# 11384            81     36       46      82           4               46
# ...             ...    ...      ...     ...         ...              ...
# 12291             3      0        0       0          -1                2
# 12292            10      0        0       0           0                7
# 12293             1      0        0       0          -1                5
# 12294             1      0        0       0           0                0
# 12295             2      0        0       0          -1                0
#
#        Point_Shares  Even_Strength_Goals  Powerplay_Goals  Shorthanded_Goals  \
# 11380          13.2                   22                8                  8
# 11381          10.6                   24               16                  1
# 11382          10.8                   19               13                  1
# 11383          11.4                   30                5                  0
# 11384          10.8                   21               14                  1
# ...             ...                  ...              ...                ...
# 12291          -0.1                    0                0                  0
# 12292          -0.2                    0                0                  0
# 12293          -0.1                    0                0                  0
# 12294           0.0                    0                0                  0
# 12295          -0.1                    0                0                  0
#
#        Game_Winning_Goals  Shots  Shooting_Percentage  Time_On_Ice  \
# 11380                   7    212                 17.9         1688
# 11381                   6    341                 12.0         1919
# 11382                   3    253                 13.0         1641
# 11383                   6    296                 11.8         1512
# 11384                   5    233                 15.5         1509
# ...                   ...    ...                  ...          ...
# 12291                   0      2                  0.0           19
# 12292                   0     10                  0.0          117
# 12293                   0      1                  0.0            8
# 12294                   0      0                  0.0            5
# 12295                   0      3                  0.0           24
#
#        Avg_Time_On_Ice  Blocks  Hits  Faceoff_Wins  Faceoff_Losses  \
# 11380        20.583333     0.0     0           0.0             0.0
# 11381        23.683333     0.0     0           0.0             0.0
# 11382        20.266667     0.0     0           0.0             0.0
# 11383        19.383333     0.0     0           0.0             0.0
# 11384        18.616667     0.0     0           0.0             0.0
# ...                ...     ...   ...           ...             ...
# 12291         6.416667     0.0     0           0.0             0.0
# 12292        11.750000     0.0     0           0.0             0.0
# 12293         7.883333     0.0     0           0.0             0.0
# 12294         5.000000     0.0     0           0.0             0.0
# 12295        12.033333     0.0     0           0.0             0.0
#
#        Faceoff_Percentage Hart_Trophy?  Votes
# 11380                 0.0          Yes   1016
# 11381                 0.0           No     59
# 11382                 0.0           No    144
# 11383                 0.0           No    176
# 11384                 0.0           No     17
# ...                   ...          ...    ...
# 12291                 0.0           No      0
# 12292                 0.0           No      0
# 12293                 0.0           No      0
# 12294                 0.0           No      0
# 12295                 0.0           No      0
#
# [916 rows x 28 columns]

# %%
# Exporting the non-salary cap players dataset
non_salary_cap_data.to_csv(os.path.join(path, '02 Data','Prepared Data', '2004_players.csv'))

# %% [markdown]
# ### Dropping Non-Salary Cap Year Data from Dataframe

# %%
# Dropping the players in the 2004 season from the dataset
nhl_cleaned1 = nhl_cleaned[nhl_cleaned.Season != 2004]

# %%
# Checking to see if the removal worked properly
nhl_cleaned1.shape
# Out:
# (12270, 28)

# %%
nhl_cleaned1.head()
# Out:
#    Season  Rank                       Player  Age Position Team  Games_Played  \
# 0    2017     1     Connor McDavid\mcdavco01   20        C  EDM            82
# 1    2017     2      Sidney Crosby\crosbsi01   29        C  PIT            75
# 2    2017     3        Patrick Kane\kanepa01   28       RW  CHI            82
# 3    2017     4  Nicklas Backstrom\backsni02   29        C  WSH            82
# 4    2017     5    Nikita Kucherov\kucheni01   23       RW  TBL            74
#
#    Goals  Assists  Points  Plus_Minus  Penalty_Minutes  Point_Shares  \
# 0     30       70     100          27               26          12.8
# 1     44       45      89          17               24          12.3
# 2     34       55      89          11               32          10.8
# 3     23       63      86          17               38           9.9
# 4     40       45      85          13               38          12.0
#
#    Even_Strength_Goals  Powerplay_Goals  Shorthanded_Goals  \
# 0                   26                3                  1
# 1                   30               14                  0
# 2                   27                7                  0
# 3                   15                8                  0
# 4                   23               17                  0
#
#    Game_Winning_Goals  Shots  Shooting_Percentage  Time_On_Ice  \
# 0                   6    251                 12.0         1733
# 1                   5    255                 17.3         1491
# 2                   5    292                 11.6         1754
# 3                   5    162                 14.2         1497
# 4                   7    246                 16.3         1438
#
#    Avg_Time_On_Ice  Blocks  Hits  Faceoff_Wins  Faceoff_Losses  \
# 0        21.133333    29.0    34         348.0           458.0
# 1        19.883333    27.0    80         842.0           906.0
# 2        21.400000    15.0    28           7.0            44.0
# 3        18.266667    33.0    45         685.0           648.0
# 4        19.433333    20.0    30           0.0             0.0
#
#    Faceoff_Percentage Hart_Trophy?  Votes
# 0                43.2          Yes   1604
# 1                48.2           No   1104
# 2                13.7           No    206
# 3                51.4           No     60
# 4                 0.0           No    119

# %%
# Exporting the main players dataset
nhl_cleaned1.to_csv(os.path.join(path, '02 Data','Prepared Data', 'nhl_players.csv'))

# %% [markdown]
# ## 04.Basic Descriptive Statistics

# %%
# Shows basic descriptive statistics for the cleaned dataset
nhl_cleaned1.describe()
# Out:
#              Season          Rank           Age  Games_Played         Goals  \
# count  12270.000000  12270.000000  12270.000000  12270.000000  12270.000000
# mean    2011.823390    499.722657     26.648574     49.132926      7.581989
# std        3.689849    335.042369      4.589184     28.695148      8.972599
# min     2006.000000      1.000000      0.000000      1.000000      0.000000
# 25%     2009.000000    236.250000     23.000000     21.000000      1.000000
# 50%     2012.000000    472.000000     26.000000     57.000000      4.000000
# 75%     2015.000000    708.000000     30.000000     76.000000     12.000000
# max     2018.000000   1728.000000     48.000000     84.000000     65.000000
#
#             Assists        Points    Plus_Minus  Penalty_Minutes  \
# count  12270.000000  12270.000000  12270.000000     12270.000000
# mean      12.981011     20.562999     -0.355175        31.973839
# std       13.340028     21.085902      9.428948        31.788168
# min        0.000000      0.000000    -42.000000         0.000000
# 25%        2.000000      3.000000     -5.000000         8.000000
# 50%        9.000000     14.000000     -1.000000        24.000000
# 75%       20.000000     32.000000      3.000000        46.000000
# max       96.000000    125.000000     50.000000       324.000000
#
#        Point_Shares  Even_Strength_Goals  Powerplay_Goals  Shorthanded_Goals  \
# count  12270.000000         12270.000000     12270.000000       12270.000000
# mean       2.497498             5.441646         1.899267           0.241076
# std        2.830529             6.178807         3.260943           0.668255
# min       -1.900000             0.000000         0.000000           0.000000
# 25%        0.200000             1.000000         0.000000           0.000000
# 50%        1.600000             3.000000         0.000000           0.000000
# 75%        4.100000             8.000000         3.000000           0.000000
# max       17.200000            48.000000        27.000000           7.000000
#
#        Game_Winning_Goals         Shots  Shooting_Percentage   Time_On_Ice  \
# count        12270.000000  12270.000000         12270.000000  12270.000000
# mean             1.197637     81.966422             7.497726    808.401793
# std              1.770925     71.767855             7.616498    577.682244
# min              0.000000      0.000000             0.000000      1.000000
# 25%              0.000000     19.000000             2.400000    238.000000
# 50%              0.000000     68.000000             7.000000    820.500000
# 75%              2.000000    127.000000            11.100000   1287.000000
# max             12.000000    528.000000           100.000000   2412.000000
#
#        Avg_Time_On_Ice        Blocks          Hits  Faceoff_Wins  \
# count     12270.000000  12270.000000  12270.000000  12270.000000
# mean         14.239730     29.580603     47.493969     62.596985
# std           4.985046     39.025661     54.357787    160.628071
# min           0.000000      0.000000      0.000000      0.000000
# 25%          10.966667      0.000000      1.000000      0.000000
# 50%          14.600000     15.000000     31.000000      0.000000
# 75%          18.000000     41.000000     75.000000     14.000000
# max          26.800000    283.000000    382.000000   1273.000000
#
#        Faceoff_Losses  Faceoff_Percentage         Votes
# count    12270.000000        12270.000000  12270.000000
# mean        62.596007           21.186805      3.197066
# std        152.593931           26.011871     53.154563
# min          0.000000            0.000000      0.000000
# 25%          0.000000            0.000000      0.000000
# 50%          0.000000            0.000000      0.000000
# 75%         19.000000           45.900000      0.000000
# max        941.000000          100.000000   1604.000000
